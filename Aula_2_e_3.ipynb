# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/gazzola/public_AlgoritmosI/blob/main/Aula_2_e_3.ipynb)

# %% [markdown]
# # Aula 2

# %% [markdown]
# ## 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# seu código

# %% [markdown]
# ## 2.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# seu código

# %% [markdown]
# # Aula 3

# %% [markdown]
# ## 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# seu código

# %% [markdown]
# ## 2.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# seu código

# %% [markdown]
# ## 3.
# ![image.png](data:image/png;base64,...)

# %%
# seu código
